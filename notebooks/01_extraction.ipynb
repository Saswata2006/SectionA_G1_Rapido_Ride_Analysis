# %% [markdown]
# # Data Extraction
#
# This notebook focuses on loading the raw dataset into the environment
# for further processing.
#
# The dataset contains ride-level transactional data including:
# - Ride details (distance, fare, service type)
# - Customer behavior (payment method)
# - Operational data (ride status, timestamps)
#
# The raw dataset is preserved in its original form to maintain data integrity.

# %% [markdown]
# ## Importing Required Libraries
#
# We use Pandas for data loading and initial inspection.

# %%
import pandas as pd

# %% [markdown]
# ## Loading the Dataset
#
# The dataset is loaded from the raw data directory.
#
# This dataset contains 50,000 ride records and will be used
# for ETL, analysis, and dashboard creation.

# %%
raw_data_path = '../data/raw/rides_data.csv'
df = pd.read_csv(raw_data_path)
df.head()
# Out:
#       services        date             time ride_status  \
# 0  cab economy  2024-07-15  08:30:40.542646   completed
# 1         auto  2024-07-05  23:36:51.542646   completed
# 2         auto  2024-07-23  11:05:37.542646   cancelled
# 3  cab economy  2024-06-24  08:45:10.542646   completed
# 4  cab economy  2024-07-15  00:26:44.542646   completed
#
#                    source               destination  duration  \
# 0         Balagere Harbor           Harohalli Nagar        39
# 1  Basavanagudi 3rd Block      Bikasipura 1st Stage        89
# 2        Babusapalya Cove         Kothaguda Terrace        25
# 3       Mahadevapura Mews            Kanakapura Arc        89
# 4         Ganganagar Cove  Basaveshwaranagar Colony        95
#
#               ride_id  distance  ride_charge  misc_charge  total_fare  \
# 0  RD3161218751875354     27.21       764.83        31.51      796.34
# 1  RD8171514284594096     34.03       314.83        49.52      364.35
# ...

# %% [markdown]
# ## Dataset Overview
#
# We inspect the structure of the dataset to understand:
# - Number of rows and columns
# - Column names
# - Data types

# %%
df.shape
# Out:
# (50000, 13)

# %%
df.columns
# Out:
# Index(['services', 'date', 'time', 'ride_status', 'source', 'destination',
#        'duration', 'ride_id', 'distance', 'ride_charge', 'misc_charge',
#        'total_fare', 'payment_method'],
#       dtype='object')

# %% [markdown]
# ## Initial Data Inspection
#
# We perform a quick inspection to identify:
# - Data types
# - Missing values
#
# This helps prepare for the cleaning stage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   services        50000 non-null  object
#  1   date            50000 non-null  object
#  2   time            50000 non-null  object
#  3   ride_status     50000 non-null  object
#  4   source          50000 non-null  object
#  5   destination     50000 non-null  object
#  6   duration        50000 non-null  int64
#  7   ride_id         50000 non-null  object
#  8   distance        50000 non-null  float64
#  9   ride_charge     44964 non-null  float64
#  10  misc_charge     44964 non-null  float64
#  11  total_fare      44964 non-null  float64
#  12  payment_method  44964 non-null  object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 5.0+ MB
